# %%
# Cài đặt (chỉ chạy 1 lần)
# !pip install llama-index chromadb youtube-transcript-api python-dotenv llama-index-vector-stores-chroma

import os
from youtube_transcript_api import YouTubeTranscriptApi
from llama_index.core import Document, VectorStoreIndex, Settings
from llama_index.vector_stores.chroma import ChromaVectorStore
from llama_index.core.node_parser import SentenceSplitter
import chromadb
import re
import sys
from pathlib import Path
from urllib.parse import parse_qs, urlparse



BACKEND_DIR = Path.cwd().parent / "backend"
sys.path.append(str(BACKEND_DIR))

from app.services.extraction import transcript_service, video_url_service

# %%
VIDEO_URL = "https://www.youtube.com/watch?v=p-N3-Q8WyfU&t=380s" 

video_id = video_url_service.extract_youtube_video_id(VIDEO_URL)
print(video_id)
# Out:
# p-N3-Q8WyfU

# %%
video_id = "p-N3-Q8WyfU"

segg, text = transcript_service.fetch_transcript(video_id)
print(segg)
# Out:
# [TranscriptSegment(text="Hello, I'm Lucy Hockings. From the BBC\xa0\nWorld Service, this is The Global Story.", start_seconds=0.28, end_seconds=7.680000000000001), TranscriptSegment(text='For many thousands of years,\xa0\nlanguage has been changing.', start_seconds=7.68, end_seconds=14.719999999999999), TranscriptSegment(text="Here in the UK, the gradual departure from\nwhat became known as the\xa0Queen's English", start_seconds=14.72, end_seconds=19.44), TranscriptSegment(text='is a trend which has often been characterised\nas a threat to cultural\xa0identity.', start_seconds=19.44, end_seconds=25.840000000000003), TranscriptSegment(text='But with the advent of social\xa0\nmedia, the pace of change', start_seconds=25.84, end_seconds=28.56), TranscriptSegment(text='may be running away from\xa0us.', start_seconds=28.56, end_seconds=29.64), TranscriptSegment(text='Phrases like "it\'s giving", "rizz", "no cap",\nthese are all terms which we attribute', start_seconds=30.68, end_seconds=3
# ...
